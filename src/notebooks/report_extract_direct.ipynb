# %% [markdown]
# # Get pdf

# %%
from pathlib import Path
ROOT_DIR = Path().resolve().parent

pdf_dir = ROOT_DIR / 'data' / 'qc_templates'

import os

files = os.listdir(pdf_dir)
pdfs = [file for file in files if file.endswith('.pdf')]
pdf_path = pdf_dir / pdfs[-1]

# %% [markdown]
# # Extract text

# %%
import pdfplumber
from tqdm.auto import tqdm

def extract_text_and_tables(pdf_path):
    all_text = []

    with pdfplumber.open(pdf_path) as pdf:
        for page_number in tqdm(range(len(pdf.pages)), desc="Processing Pages", unit="page"):
            page = pdf.pages[page_number]

            # Extract text
            text = page.extract_text()
            all_text.append(f"\n--- Page {page_number + 1} ---\n" + (text if text else ""))

    return all_text

all_text = extract_text_and_tables(pdf_path)
all_text
# Out:
# Processing Pages:   0%|          | 0/30 [00:00<?, ?page/s]
# ['\n--- Page 1 ---\nIntake QC Inspection Summary Report 19/01/2025\nCustomer GNK€ PO 177193\nSupplier Code :GNK€\nSupplier :G.GIANNAKAKIS SA\nCOO : Greece\nVehicle No : Expected ETA : 18/01/2025 00:00:00\nVessel : DELAPORTAS Haulier : Received : 19/01/2025 08:15:09\nDP : 51 - Glinwell Temperature : Min 0.00; Max 0.00; Avg 0.00 Recorder (s) : NO Inspection Date : 19/01/2025 12:32:00\nProduct Details Pallet Cust Supplier Pallet GGN Number Harvest End Packhouse Organic PLU Minor Major Waste QA Comments Brix Pressure Maturity% Total Est RAG\nID Pallet ID /Grower Date Customer Avg % Avg Kg 1 2 3 4 5 Defects Yield\nCucumbers 18 Loose 6194840 6194840 Tesco NO 5.6% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 5.6% 100.00 BLUE\n(N/A) LSEEX and untidy wrap present. 150\nCucumbers 18 Loose 6194843 6194843 Tesco NO 5.6% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 5.6% 100.00 BLUE\n(N/A) LSEEX and untidy wrap present. 150\nCucumbers 28 Loose 6194842 6194842 Tesco NO 8.3% 0.00% 0.00% No major issues, flowering, 0.00 0.00 0, 0, 0, 0, 0 8.3% 100.00 BLUE\n(N/A) LARGE curvature and untidy wrap 65\npresent.\nCucumbers 28 Loose 6194864 6194864 Tesco NO 8.3% 0.00% 0.00% No major issues, flowering, 0.00 0.00 0, 0, 0, 0, 0 8.3% 100.00 BLUE\n(N/A) LARGE curvature and untidy wrap 65\npresent.\nCucumbers 28 Loose 6194865 6194865 Tesco NO 8.3% 0.00% 0.00% No major issues, flowering, 0.00 0.00 0, 0, 0, 0, 0 8.3% 100.00 BLUE\n(N/A) LARGE curvature and untidy wrap 65\npresent.\nCucumbers 38 Loose 6194841 6194841 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194844 6194844 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194845 6194845 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194846 6194846 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194847 6194847 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.',
#  '\n--- Page 2 ---\nCucumbers 38 Loose 6194848 6194848 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194849 6194849 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194850 6194850 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194851 6194851 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194852 6194852 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194853 6194853 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194854 6194854 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194855 6194855 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194856 6194856 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194857 6194857 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194858 6194858 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194859 6194859 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194860 6194860 Tesco NO 4.4% 0.00% 0.00% No BE labels applied. No 0.00 0.00 0, 0, 0, 0, 0 4.4% 100.00 BLACK\n(N/A) LSE major issues, 65\nmiswrap/untidy wrap\nCucumbers 38 Loose 6194861 6194861 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.\nCucumbers 38 Loose 6194862 6194862 Tesco NO 6.1% 0.00% 0.00% No major issues, flowering 0.00 0.00 0, 0, 0, 0, 0 6.1% 100.00 BLUE\n(N/A) LSE and miswrap/untidy wrap 65\npresent.',
#  '\n--- Page 3 ---\nCucumbers 38 Loose 6194863 6194863 Tesco NO 3.5% 0.00% 0.00% No BE labels applied. No 0.00 0.00 0, 0, 0, 0, 0 3.5% 100.00 BLACK\n(N/A) LSE major issues, 65\nmiswrap/untidy wrap',
#  '\n--- Page 4 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 18 Loose\nPallet ID : 6194840 Freshness Technology :\nSupplier Pallet ID : 6194840 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSEEX / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 150\nOrchard/Farm : End Customer : Tesco\nReceived Qty 150\nHarvest Date : DP : 51\nTotal Defects : 5.56%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676779 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 4.63%\nMinor : Flowering: 0.93%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10056547\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 5.56% Minor Fruit Total : 6.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%\nWeight Readings : 264 267 269 276 277 281 282 284 286 308\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 108\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 4 of 30',
#  '\n--- Page 5 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194841 Freshness Technology :\nSupplier Pallet ID : 6194841 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 5 of 30',
#  '\n--- Page 6 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 28 Loose\nPallet ID : 6194842 Freshness Technology :\nSupplier Pallet ID : 6194842 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LARGE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 8.33%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676781 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 1.19%\nMinor : Curvature: 1.19%\nMinor : Miswrap/Untidy Wrap: 5.95%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 03239988\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 8.33% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 498g; Min 469g; Max 528g Underweight 0%\nWeight Readings : 469 472 482 483 492 503 508 517 524 528\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering, curvature and untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 84\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 6 of 30',
#  '\n--- Page 7 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 18 Loose\nPallet ID : 6194843 Freshness Technology :\nSupplier Pallet ID : 6194843 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSEEX / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 150\nOrchard/Farm : End Customer : Tesco\nReceived Qty 150\nHarvest Date : DP : 51\nTotal Defects : 5.56%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676779 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.93%\nMinor : Miswrap/Untidy Wrap: 4.63%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10056547\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 5.56% Minor Fruit Total : 6.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%\nWeight Readings : 264 267 269 276 277 281 282 284 286 308\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 108\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 7 of 30',
#  '\n--- Page 8 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194844 Freshness Technology :\nSupplier Pallet ID : 6194844 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 8 of 30',
#  '\n--- Page 9 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194845 Freshness Technology :\nSupplier Pallet ID : 6194845 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 9 of 30',
#  '\n--- Page 10 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194846 Freshness Technology :\nSupplier Pallet ID : 6194846 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 10 of 30',
#  '\n--- Page 11 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194847 Freshness Technology :\nSupplier Pallet ID : 6194847 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 11 of 30',
#  '\n--- Page 12 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194848 Freshness Technology :\nSupplier Pallet ID : 6194848 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 12 of 30',
#  '\n--- Page 13 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194849 Freshness Technology :\nSupplier Pallet ID : 6194849 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 13 of 30',
#  '\n--- Page 14 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194850 Freshness Technology :\nSupplier Pallet ID : 6194850 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 14 of 30',
#  '\n--- Page 15 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194851 Freshness Technology :\nSupplier Pallet ID : 6194851 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 15 of 30',
#  '\n--- Page 16 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194852 Freshness Technology :\nSupplier Pallet ID : 6194852 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 16 of 30',
#  '\n--- Page 17 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194853 Freshness Technology :\nSupplier Pallet ID : 6194853 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 17 of 30',
#  '\n--- Page 18 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194854 Freshness Technology :\nSupplier Pallet ID : 6194854 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 18 of 30',
#  '\n--- Page 19 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194855 Freshness Technology :\nSupplier Pallet ID : 6194855 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 19 of 30',
#  '\n--- Page 20 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194856 Freshness Technology :\nSupplier Pallet ID : 6194856 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 20 of 30',
#  '\n--- Page 21 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194857 Freshness Technology :\nSupplier Pallet ID : 6194857 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 21 of 30',
#  '\n--- Page 22 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194858 Freshness Technology :\nSupplier Pallet ID : 6194858 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 22 of 30',
#  '\n--- Page 23 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194859 Freshness Technology :\nSupplier Pallet ID : 6194859 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 23 of 30',
#  '\n--- Page 24 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194860 Freshness Technology :\nSupplier Pallet ID : 6194860 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLACK Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 4.39%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 4.39%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : NO BE LABELS A\nCOO Printed match on Pack and Label? : YES Boxend Barcode: NO BE LABELS SPPLIEDLabel Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 4.39% Minor Fruit Total : 5.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 326g; Min 302g; Max 342g Underweight 0%\nWeight Readings : 302 314 315 318 326 329 338 338 339 342\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues : Curled Box End Labels\nQA Comments : No BE labels applied. No major issues, miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 24 of 30',
#  '\n--- Page 25 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194861 Freshness Technology :\nSupplier Pallet ID : 6194861 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 0.88%\nMinor : Miswrap/Untidy Wrap: 5.26%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 25 of 30',
#  '\n--- Page 26 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194862 Freshness Technology :\nSupplier Pallet ID : 6194862 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 6.14%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.26%\nMinor : Flowering: 0.88%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 6.14% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%\nWeight Readings : 315 317 320 322 325 329 336 338 341 362\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering and miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 26 of 30',
#  '\n--- Page 27 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 38 Loose\nPallet ID : 6194863 Freshness Technology :\nSupplier Pallet ID : 6194863 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LSE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLACK Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 3.51%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676780 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 3.51%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : NO BE LABELS A\nCOO Printed match on Pack and Label? : YES Boxend Barcode: NO BE LABELS APPLIEDLabel Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 10015599\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 3.51% Minor Fruit Total : 4.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 328g; Min 309g; Max 366g Underweight 0%\nWeight Readings : 309 312 316 324 325 326 326 338 341 366\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues : Curled Box End Labels\nQA Comments : No BE labels applied. No major issues, miswrap/untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 114\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 27 of 30',
#  '\n--- Page 28 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 28 Loose\nPallet ID : 6194864 Freshness Technology :\nSupplier Pallet ID : 6194864 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LARGE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 8.33%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676781 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Flowering: 1.19%\nMinor : Curvature: 1.19%\nMinor : Miswrap/Untidy Wrap: 5.95%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 03239988\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 8.33% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 498g; Min 469g; Max 528g Underweight 0%\nWeight Readings : 469 472 482 483 492 503 508 517 524 528\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering, curvature and untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 84\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 28 of 30',
#  '\n--- Page 29 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nCucumbers 28 Loose\nPallet ID : 6194865 Freshness Technology :\nSupplier Pallet ID : 6194865 Punnet / Pad Type : / N/A\nCustomer Pallet ID : Outer : / Tray Type :\nVariety : Not Available Brand : LARGE / Class : 1\nGrower : / Organic? : NO Does Pallet Meet Spec? : YES\nGGN : PLU? :\nBLUE Expected Qty 65\nOrchard/Farm : End Customer : Tesco\nReceived Qty 65\nHarvest Date : DP : 51\nTotal Defects : 8.33%\nSize/Calibre : Packhouse :\nEstimated Yield : 100.00%\nLot Number : 676781 Inspector : Marzena.Buslowicz\nBB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A\nAlphanumeric Date Code : A27\nMinor : Miswrap/Untidy Wrap: 5.95%\nMinor : Flowering: 1.19%\nMinor : Curvature: 1.19%\nBB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE\nCOO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :\nVariety Printed match on Pack and Label? : YES Pack Barcode: 03239988\nWaste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0\nMinor Defects Tot : 8.33% Minor Fruit Total : 7.00\nMajor Defects Tot : 0.00% Major Fruit Total : 0.00\nBox / Pack Weights : Avg 498g; Min 469g; Max 528g Underweight 0%\nWeight Readings : 469 472 482 483 492 503 508 517 524 528\nFruit Weights : Avg 0.00g\nSugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%\nBrix Readings :\nSize : Min 0; Max 0 Undersize 0.00%\nSize Readings :\nMaturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0\nPressures : Avg 0.00 ; Min 0.00 ; Max 0.00\nOther Issues :\nQA Comments : No major issues, flowering, curvature and untidy wrap present.\nPacks/Fruits Inspected/Sample Size : 84\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 29 of 30',
#  '\n--- Page 30 ---\nIntake Pallet QC Inspection Report\nCustomer GNK€ PO 177193\nSupplier Code: GNK€\nSupplier : G.GIANNAKAKIS SA\nCOO: Greece\nVehicle No : Received : 19/01/2025 08:15:09\nVessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025\nC:\\Users\\MARZEN~2.BUS\\AppData\\Local\\Temp\\3\\md7ABF.tmp Page 30 of 30']

# %%
import re
# Regular expression pattern to match "Intake Pallet QC Inspection Report" with a page header
pattern = re.compile(r"^\n--- Page \d+ ---\nIntake Pallet QC Inspection Report", re.MULTILINE)

# Filtering the list
filtered_blocks = [block for block in all_text if pattern.search(block)]
last_block_len = len(filtered_blocks[-1])

# remove last pages with only images
final_items = [block for block in filtered_blocks if len(block)>last_block_len]

print(final_items[0])
# Out:
# --- Page 4 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 4 of 30

# %% [markdown]
# # Using very small model due to collab limitations

# %%
import os
import json
import torch
from tqdm.auto import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import sys

# Ensure the parent directory is in the path
sys.path.append('..')
from configs.report_config import get_qc_prompt

# Load 4-bit Quantized Model
print("Loading model and tokenizer...")

model_name = "Qwen/Qwen2.5-14B"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True, 
    bnb_4bit_compute_dtype=torch.bfloat16  # Set computation dtype
)

model = AutoModelForCausalLM.from_pretrained(
    model_name, 
    quantization_config=bnb_config,  # Apply quantization during loading
    device_map="auto"
)

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

print("Model loaded successfully!")

# Create output directory
output_folder = "qc_reports_14b"
os.makedirs(output_folder, exist_ok=True)

# Function to generate JSON output directly from the model
def generate_json_output(prompt):
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    with torch.no_grad():
        outputs = model.generate(**inputs)
    
    # Decode and clean up response
    response = tokenizer.decode(outputs[0])
    return response

responses = []
# Process each page
for i, page in enumerate(tqdm(final_items, desc="Processing Pages", unit="page")):
    prompt = get_qc_prompt(page)  # Get structured prompt
    response = generate_json_output(prompt)  # Ask model directly for JSON
    responses.append(response)
    if i > 1:
        break
    # Save JSON output
    # output_path = os.path.join(output_folder, f"qc_report_page_{i}.json")
    # with open(output_path, "w", encoding="utf-8") as json_file:
    #     json.dump(response, json_file, indent=4, ensure_ascii=False)

    # print(f"Saved: {output_path}")
# Out:
# Loading model and tokenizer...
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Model loaded successfully!
# Processing Pages:   0%|          | 0/26 [00:00<?, ?page/s]
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.

# %%
for response in responses:
    print(response[len(prompt):])
# Out:
# 5 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 5 of 30
# Boxes Inspected : 108
# --- Page 6 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 108
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 1005654
# ge 6 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 6.14% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%
# Weight Readings : 315 317 320 322 325 329 336 338 341 362
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and miswrap/untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 114
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 114
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 6.14% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%
# Weight Readings : 315 317 320 322 325 329 336 338 341 362
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and miswrap/untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 114
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 7 of 30
# Boxes Inspected : 114
# --- Page 8 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# W

# %%
for response in responses:
    print(response[len(prompt):])
# Out:
# xes Inspected : 108
# --- Page 5 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 5 of 30
# Boxes Inspected : 108
# --- Page 6 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 108
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 1005654
#
# Boxes Inspected : 114
# --- Page 6 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 6.14% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%
# Weight Readings : 315 317 320 322 325 329 336 338 341 362
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and miswrap/untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 114
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 114
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 6.14% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 331g; Min 315g; Max 362g Underweight 0%
# Weight Readings : 315 317 320 322 325 329 336 338 341 362
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and miswrap/untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 114
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 7 of 30
# Boxes Inspected : 114
# --- Page 8 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 38 Loose
# Pallet ID : 6194841 Freshness Technology :
# Supplier Pallet ID : 6194841 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 6.14%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676780 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.88%
# Minor : Miswrap/Untidy Wrap: 5.26%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 300/400 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05059316573086 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10015599
# W
# emp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 1
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 28 Loose
# Pallet ID : 6194843 Freshness Technology :
# Supplier Pallet ID : 6194843 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LARGE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 8.33%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676781 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 1.19%
# Minor : Curvature: 1.19%
# Minor : Miswrap/Untidy Wrap: 5.95%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 03239988
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 8.33% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 498g; Min 469g; Max 528g Underweight 0%
# Weight Readings : 469 472 482 483 492 503 508 517 524 528
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering, curvature and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 84
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 7 of 30
# Boxes Inspected : 1
# --- Page 8 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 28 Loose
# Pallet ID : 6194844 Freshness Technology :
# Supplier Pallet ID : 6194844 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LARGE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 8.33%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676781 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 1.19%
# Minor : Curvature: 1.19%
# Minor : Miswrap/Untidy Wrap: 5.95%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 03239988
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 8.33% Minor Fruit Total : 7.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 498g; Min 469g; Max 528g Underweight 0%
# Weight Readings : 469 472 482 483 492 503 508 517 524 528
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering, curvature and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 84
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 8 of 30
# Boxes Inspected : 1
# --- Page 9 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 28 Loose
# Pallet ID : 6194845 Freshness Technology :
# Supplier Pallet ID : 6194845 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LARGE / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 65
# Orchard/Farm : End Customer : Tesco
# Received Qty 65
# Harvest Date : DP : 51
# Total Defects : 8.33%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676781 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 1.19%
# Minor : Curvature: 1.19%
# Minor : Miswrap/Untidy Wrap: 5.95%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 450/550 Label Colour : WHITE
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05053526135188 Label Type :
# Variety Printed match on
# xes Inspected : 108
# --- Page 8 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194843 Freshness Technology :
# Supplier Pallet ID : 6194843 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.93%
# Minor : Miswrap/Untidy Wrap: 4.63%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 8 of 30
# Boxes Inspected : 108
# --- Page 9 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194843 Freshness Technology :
# Supplier Pallet ID : 6194843 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.93%
# Minor : Miswrap/Untidy Wrap: 4.63%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 9 of 30
# Boxes Inspected : 108
# --- Page 10 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194843 Freshness Technology :
# Supplier Pallet ID : 6194843 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Flowering: 0.93%
# Minor : Miswrap/Untidy Wrap: 4.63%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 100565

# %%
def extract_json_objects(text):
    json_pattern = r'\{.*?\}'
    json_matches = re.findall(json_pattern, text, re.DOTALL)  # Find all JSON objects
    json_objects = []
    
    for match in json_matches:
        try:
            json_obj = json.loads(match)  # Convert to dictionary
            json_objects.append(json_obj)
        except json.JSONDecodeError:
            continue  # Ignore invalid JSON
    
    return json_objects

extract_json_objects(responses[0])
# Out:
# []

# %%
print(responses[0])
# Out:
# You are an advanced quality control report extractor. Extract structured quality control details from the provided text and return a **valid JSON object** that strictly follows this schema. **Do not return extra text, explanations, or comments.**
#
# ### **Schema:**
# {
#   "product_name": "string",
#   "RAG": "string",
#   "expected_qty": "string",
#   "received_qty": "string",
#   "supplier_code": "string",
#   "supplier": "string",
#   "coo": "string",
#   "received_date": "YYYY-MM-DD HH:MM:SS",
#   "inspection_date": "YYYY-MM-DD HH:MM:SS",
#   "print_date": "YYYY-MM-DD",
#   "iss_pallet_id": "integer",
#   "supplier_pallet_id": "integer",
#   "customer_pallet_id": "integer",
#   "variety": "string",
#   "brand": "string",
#   "organic": "YES" or "NO",
#   "does_pallet_meet_spec": "YES" or "NO",
#   "end_customer": "string",
#   "harvest_date": "YYYY-MM-DD",
#   "dp": "string",
#   "total_defects": "integer",
#   "size_calibre": "integer",
#   "lot_number": "string",
#   "inspector": "string",
#   "estimated_yield": "string",
#   "defects_fruit_total": "integer",
#   "packs_with_defects": "integer",
#   "waste_tot": "integer",
#   "waste_fruit_total": "integer",
#   "packs_with_waste": "integer",
#   "minor_defects_tot": "integer",
#   "minor_fruit_total": "integer",
#   "major_defects_tot": "integer",
#   "major_fruit_total": "integer",
#   "packs_with_major": "integer",
#   "box_pack_weights": "string",
#   "weight_readings": "string",
#   "fruit_weights": "string",
#   "qa_comments": "string",
#   "packs_fruits_inspected_sample_size": "integer",
#   "boxes_inspected": "integer"
# }
#
# ### **Strict Extraction Rules:**
# - RAG will be the color eg: RED, GREEN, BLUE, AMBER etc... look a color from the text- Some fields would be empty if you find large space founwed with a `anyname :` then keep null- Extract values **exactly as they appear** in the text.
# - If a field is **missing**, return it as **null**.
# - Do **not** infer or add extra information.
# - Remove unnecessary spaces from extracted values.
# - Output must be **pure JSON** with **no explanations, notes, or formatting errors**.
#
# ### **Page Text:**
#
# --- Page 4 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 4 of 30
# Boxes Inspected : 108
# --- Page 5 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 5 of 30
# Boxes Inspected : 108
# --- Page 6 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 10056547
# Waste Tot : 0.00% Waste Fruit Total : 0.00 Packs With Waste : 0
# Minor Defects Tot : 5.56% Minor Fruit Total : 6.00
# Major Defects Tot : 0.00% Major Fruit Total : 0.00
# Box / Pack Weights : Avg 279g; Min 264g; Max 308g Underweight 0%
# Weight Readings : 264 267 269 276 277 281 282 284 286 308
# Fruit Weights : Avg 0.00g
# Sugar Brix : Avg 0.00%; Min 0.00%; Max 0.00%
# Brix Readings :
# Size : Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0 / ST2: 0 / ST3: 0 / ST4: 0 / ST5: 0
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : No major issues, flowering and untidy wrap present.
# Packs/Fruits Inspected/Sample Size : 108
# C:\Users\MARZEN~2.BUS\AppData\Local\Temp\3\md7ABF.tmp Page 6 of 30
# Boxes Inspected : 108
# --- Page 7 ---
# Intake Pallet QC Inspection Report
# Customer GNK€ PO 177193
# Supplier Code: GNK€
# Supplier : G.GIANNAKAKIS SA
# COO: Greece
# Vehicle No : Received : 19/01/2025 08:15:09
# Vessel: DELAPORTAS Inspection Date : 19/01/2025 12:32:00 Print date : 19/01/2025
# Cucumbers 18 Loose
# Pallet ID : 6194840 Freshness Technology :
# Supplier Pallet ID : 6194840 Punnet / Pad Type : / N/A
# Customer Pallet ID : Outer : / Tray Type :
# Variety : Not Available Brand : LSEEX / Class : 1
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : PLU? :
# BLUE Expected Qty 150
# Orchard/Farm : End Customer : Tesco
# Received Qty 150
# Harvest Date : DP : 51
# Total Defects : 5.56%
# Size/Calibre : Packhouse :
# Estimated Yield : 100.00%
# Lot Number : 676779 Inspector : Marzena.Buslowicz
# BB/DU Date : 27/01/2025 Ribon/Promo : N/A / N/A
# Alphanumeric Date Code : A27
# Minor : Miswrap/Untidy Wrap: 4.63%
# Minor : Flowering: 0.93%
# BB/DU Printed match on Pack and Label? : YES Weight Printed: 260/360 Label Colour : YELLOW
# COO Printed match on Pack and Label? : YES Boxend Barcode: 05054402688316 Label Type :
# Variety Printed match on Pack and Label? : YES Pack Barcode: 1005654
