# %%
from config.settings import SRC_DIR
import os
os.chdir(SRC_DIR)

# %%
from document_processing_system.components.data_ingestion import DataIngestion
from document_processing_system.components.data_extraction import DataExtraction

pdf = 'PO166939-204865'

data_ingester = DataIngestion(f'qc_data/qc_templates/{pdf}.pdf')
data_extracter = DataExtraction(data_ingester)
pages, tables, images = data_extracter.extract_data()
all_items = data_extracter.filter_pages(pages)
data_extracter.display_data(all_items)
# Out:
# Extracting pages:   0%|          | 0/15 [00:00<?, ?pages/s]
# Filtering pages:   0%|          | 0/15 [00:00<?, ?pages/s]
# --------Page: 2-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761770 Freshness Technology :
# Supplier Pallet ID : 5808239 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808239 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 340g ; Min 326g; Max 367g Underweight 0%
# Weight Readings : 326 326 328 330 330 331 332 333 334 334 342 343 343 347 349 350 352 353 353
# 367
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.04%; Min 14.90%; Max 17.60%
# Brix Readings : 14.9 15.0 15.4 15.6 15.7 16.1 16.2 16.8 17.1 17.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Isolated underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 2 of 15
#
# --------Page: 3-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761771 Freshness Technology :
# Supplier Pallet ID : 5808238 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808238 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508165 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 3 of 15
#
# --------Page: 4-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763099 Freshness Technology :
# Supplier Pallet ID : 7763099 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 345g ; Min 324g; Max 361g Underweight 0%
# Weight Readings : 324 330 331 335 337 338 341 341 341 346 347 347 350 351 351 352 354 355 360
# 361
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.14%; Min 13.30%; Max 18.20%
# Brix Readings : 13.3 14.3 15.4 15.5 16.0 16.4 16.8 17.6 17.9 18.2
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Isolated underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 4 of 15
#
# --------Page: 5-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763100 Freshness Technology :
# Supplier Pallet ID : 7763100 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Puncture: 1.67%
# Minor : Scarring: 1.67%
# Major : Dry Splits: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 348g ; Min 330g; Max 380g Underweight 0%
# Weight Readings : 330 331 332 333 336 340 341 343 346 346 347 348 348 355 355 357 357 359 366
# 380
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 14.76%; Min 13.60%; Max 16.90%
# Brix Readings : 13.6 13.8 14.1 14.1 14.1 14.3 15.1 15.6 16.0 16.9
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 5 of 15
#
# --------Page: 6-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763101 Freshness Technology :
# Supplier Pallet ID : 7763101 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 341g ; Min 324g; Max 359g Underweight 0%
# Weight Readings : 324 332 333 336 336 337 337 339 339 340 340 340 341 341 343 344 346 351 354
# 359
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.59%; Min 14.50%; Max 18.80%
# Brix Readings : 14.5 15.4 16.3 16.4 16.4 16.5 16.6 17.2 17.8 18.8
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Isolated underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 6 of 15
#
# --------Page: 7-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763102 Freshness Technology :
# Supplier Pallet ID : 7763102 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 35/40 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Puncture: 0.83%
# Minor : Scarring: 1.67%
# Major : Bruising: 1.67%
# Major : Dry Splits: 0.83%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 350g ; Min 327g; Max 379g Underweight 0%
# Weight Readings : 327 335 339 339 340 341 341 341 344 346 347 354 357 358 359 362 362 363 365
# 379
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 13.19%; Min 12.20%; Max 14.80%
# Brix Readings : 12.2 12.2 12.2 12.7 12.7 12.8 13.7 14.1 14.5 14.8
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 7 of 15
#
# --------Page: 8-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763103 Freshness Technology :
# Supplier Pallet ID : 7763103 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 35/40 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 325g ; Min 313g; Max 340g Underweight 0%
# Weight Readings : 313 315 320 320 321 321 322 322 322 323 324 325 325 326 330 330 331 332 339
# 340
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 15.24%; Min 13.10%; Max 17.30%
# Brix Readings : 13.1 14.1 14.5 14.8 15.3 15.5 15.6 15.6 16.6 17.3
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 8 of 15
#
# --------Page: 9-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763104 Freshness Technology :
# Supplier Pallet ID : 7763104 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 35/40 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 1.67%
# Major : Dry Splits: 0.83%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 343g ; Min 328g; Max 363g Underweight 0%
# Weight Readings : 328 336 337 337 338 338 339 341 341 341 342 344 344 345 346 346 347 348 353
# 363
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 15.20%; Min 11.60%; Max 19.60%
# Brix Readings : 11.6 12.5 14.2 14.2 15.0 15.3 15.4 15.5 18.7 19.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 9 of 15
#
# --------Page: 10-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763105 Freshness Technology :
# Supplier Pallet ID : 7763105 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508165 Inspector : Hanna.Dziuba
# Minor : Puncture: 1.67%
# Minor : Scarring: 1.67%
# Major : Dry Splits: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 343g ; Min 330g; Max 360g Underweight 0%
# Weight Readings : 330 330 331 331 331 332 332 335 335 339 345 346 347 349 352 354 356 358 360
# 360
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 13.85%; Min 12.20%; Max 15.50%
# Brix Readings : 12.2 12.7 12.8 12.8 13.1 14.4 14.4 15.1 15.5 15.5
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 10 of 15
#
# --------Page: 11-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7763106 Freshness Technology :
# Supplier Pallet ID : 7763106 Punnet / Pad Type : N/A /
# Customer Pallet ID : Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508165 Inspector : Hanna.Dziuba
# Minor : Puncture: 1.67%
# Minor : Scarring: 1.67%
# Major : Dry Splits: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 343g ; Min 330g; Max 357g Underweight 0%
# Weight Readings : 330 334 335 336 336 337 338 339 342 343 344 345 345 347 347 349 350 355 356
# 357
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.56%; Min 13.50%; Max 19.20%
# Brix Readings : 13.5 14.1 14.3 15.9 16.7 17.1 18.0 18.3 18.5 19.2
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 11 of 15

# %%
documnet = ''

for page in all_items[:2]:
    documnet += page

print(documnet)
# Out:
# --------Page: 2-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761770 Freshness Technology :
# Supplier Pallet ID : 5808239 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808239 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 340g ; Min 326g; Max 367g Underweight 0%
# Weight Readings : 326 326 328 330 330 331 332 333 334 334 342 343 343 347 349 350 352 353 353
# 367
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.04%; Min 14.90%; Max 17.60%
# Brix Readings : 14.9 15.0 15.4 15.6 15.7 16.1 16.2 16.8 17.1 17.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Isolated underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 2 of 15
# --------Page: 3-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761771 Freshness Technology :
# Supplier Pallet ID : 5808238 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808238 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508165 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 3 of 15

# %%
import os
from document_processing_system.components.model_inference import ModelInference
from config.settings import DATA_DIR

# Define the PDF folder path
pdf_folder = os.path.join(DATA_DIR, 'qc_data', 'qc_reports_output', pdf, 'qc_reports_14b')

# Ensure the directory exists
os.makedirs(pdf_folder, exist_ok=True)

# Initialize the model
# model = ModelInference(model_name="Qwen/Qwen2.5-14B")

# %%
from config.purpose.multi_page_dps_qc_report_config import get_qc_prompt
from utils.post_processing import extract_json_objects

class FullDocumentModelInference(ModelInference):
    def __init__(self, model_name="deepseek-ai/DeepSeek-R1-Distill-Qwen-14B", max_tokens=10_000):
        super().__init__(model_name)
        self.max_tokens = max_tokens

    def generate_json(self, text):
        """Overrides `generate_json` to allow max_tokens modification"""
        outputs = self.llm_pipeline(
            text,
            max_new_tokens=self.max_tokens
        )
        response = outputs[0]["generated_text"]
        # json_response = extract_json_objects(response)
        return response

    def process_items(self, document):
        """Processes a full document and extracts structured data."""
        prompt = get_qc_prompt(document)
        response = self.generate_json(prompt)
        return response

# %%
# Process items
model = FullDocumentModelInference(model_name="Qwen/Qwen2.5-14B")
response = model.process_items(documnet)
# Out:
# INFO:root:Loading model and tokenizer...
# INFO:accelerate.utils.modeling:We will use 90% of the memory on device 0 for storing the model, and 10% for the buffer to avoid OOM. You can set `max_memory` in to a higher value to use more memory (at your own risk).
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0
# INFO:root:Model loaded successfully!

# %%
print(response)
# Out:
# I have multiple pages get the list of itemsYou are an expert quality control data extraction specialist. Your task is to extract structured quality control details from the provided text, which represents multiple pages from a QC report. Each page may contain details for multiple products. The report originates from a fresh produce distribution center and is used for internal quality control purposes.
#
# You must return a **valid JSON array** where each product is a separate JSON object. **Do not return extra text, explanations, or comments.**
#
# ### **Schema:**
# [
#   {
#     "product_name": "string", // The name of the product (e.g., 'Strawberries', 'Organic Blueberries') along with quantity (eg: 20x227g Punnet, 20x320g Punnet).
#     "RAG": "string", // A color code indicating quality status (e.g., 'RED', 'GREEN', 'BLUE', 'AMBER'). If not explicitly a color, use null.
#     "expected_qty": "string", // The expected quantity of the product.
#     "received_qty": "string", // The quantity of the product actually received.
#     "supplier_code": "string", // The code identifying the supplier.
#     "supplier": "string", // The name of the supplier.
#     "coo": "string", // Country of Origin.
#     "received_date": "YYYY-MM-DD HH:MM:SS", // The date and time the product was received. If time is unavailable, use 00:00:00.
#     "inspection_date": "YYYY-MM-DD HH:MM:SS", // The date and time of the inspection. If time is unavailable, use 00:00:00.
#     "print_date": "YYYY-MM-DD", // The date the report was printed.
#     "iss_pallet_id": "integer", // The internal pallet ID. If not a valid integer, use null.
#     "supplier_pallet_id": "integer", // The supplier's pallet ID. If not a valid integer, use null.
#     "customer_pallet_id": "integer", // The customer's pallet ID. If not a valid integer, use null.
#     "variety": "string", // The variety of the product (e.g., 'Chandler', 'Duke').
#     "brand": "string", // The brand of the product.
#     "organic": "YES" or "NO", // Indicates whether the product is organic.
#     "does_pallet_meet_spec": "YES" or "NO", // Indicates whether the pallet meets specifications.
#     "end_customer": "string", // The final customer for the product.
#     "harvest_date": "YYYY-MM-DD", // The date the product was harvested.
#     "dp": "integer", // Distribution Point.
#     "total_defects_percentage": "float", // The total number of defects found. If not a valid integer, use null.
#     "size_calibre": "string", // The size or calibre of the product (e.g., '35/40').
#     "lot_number": "integer", // The lot number of the product.
#     "inspector": "string", // The name of the inspector.
#     "estimated_yield_percentage": "float", // The estimated yield of the product.
#     "defects_fruit_total": "integer", // The total number of defective fruits. If not a valid integer, use null.
#   }
# ]
#
# ### **Strict Extraction Rules:**
# - Each extracted JSON object must represent a single product.
# - Extract all products from the provided text, ensuring no duplicate or missing items.
# - Maintain the correct data types for each field.
# - If a field is missing, return it as null.
# - The output must be **pure JSON** with **no explanations, notes, or formatting errors**.
# - Return exactly **one JSON array** containing **multiple JSON objects**.
# - If a date field contains only the year, month, and day, set the time to 00:00:00.
# - If a numerical field contains non-numeric characters, remove them before converting to an integer. If the field cannot be converted to an integer, return null.
#
# ### **Page Texts:**
#
# --------Page: 2-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761770 Freshness Technology :
# Supplier Pallet ID : 5808239 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808239 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# BLUE Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 5.00%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 100%
# Lot Number : 508164 Inspector : Hanna.Dziuba
# Minor : Dry Splits: 1.67%
# Minor : Puncture: 1.67%
# Major : Scarring: 1.67%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 0.00% Waste Fruit Total : 0 Packs With Waste : 0%
# Minor Defects Tot : 3.33% Minor Fruit Total : 2
# Major Defects Tot : 1.67% Major Fruit Total : 1 Packs With Major : 0%
# Box / Pack Weights : Avg 340g ; Min 326g; Max 367g Underweight 0%
# Weight Readings : 326 326 328 330 330 331 332 333 334 334 342 343 343 347 349 350 352 353 353
# 367
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 16.04%; Min 14.90%; Max 17.60%
# Brix Readings : 14.9 15.0 15.4 15.6 15.7 16.1 16.2 16.8 17.1 17.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Dry splits. Scarring. Isolated puncture. Isolated condensation punnets. Isolated underweight punnets.
# .
# Packs/Fruits Inspected/Sample Size : 60
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 2 of 15
# --------Page: 3-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761771 Freshness Technology :
# Supplier Pallet ID : 5808238 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808238 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508165 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 3 of 15
# --------Page: 4-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761772 Freshness Technology :
# Supplier Pallet ID : 5808237 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808237 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508166 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 4 of 15
# --------Page: 5-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761773 Freshness Technology :
# Supplier Pallet ID : 5808236 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808236 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508167 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 5 of 15
# --------Page: 6-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761774 Freshness Technology :
# Supplier Pallet ID : 5808235 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808235 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508168 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 6 of 15
# --------Page: 7-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761775 Freshness Technology :
# Supplier Pallet ID : 5808234 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808234 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508169 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 7 of 15
# --------Page: 8-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761776 Freshness Technology :
# Supplier Pallet ID : 5808233 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808233 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508170 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 8 of 15
# --------Page: 9-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761777 Freshness Technology :
# Supplier Pallet ID : 5808232 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808232 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508171 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 9 of 15
# --------Page: 10-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761778 Freshness Technology :
# Supplier Pallet ID : 5808231 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808231 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508172 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 10 of 15
# --------Page: 11-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761779 Freshness Technology :
# Supplier Pallet ID : 5808230 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808230 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508173 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 11 of 15
# --------Page: 12-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761780 Freshness Technology :
# Supplier Pallet ID : 5808229 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808229 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508174 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 12 of 15
# --------Page: 13-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761781 Freshness Technology :
# Supplier Pallet ID : 5808228 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808228 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508175 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 13 of 15
# --------Page: 14-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761782 Freshness Technology :
# Supplier Pallet ID : 5808227 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808227 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508176 Inspector : Hanna.Dziuba
# Waste : Waste: 2.50%
# Minor : Bruising: 2.50%
# Minor : Dry Splits: 0.83%
# Minor : Puncture: 0.83%
# Minor : Scarring: 0.83%
# Major : Bruising: 2.50%
# Major : Scarring: 0.83%
# Defects Tot : 0.00% Defects Fruit Total : 0 Packs With Defects : 0.00%
# Waste Tot : 2.50% Waste Fruit Total : 3 Packs With Waste : 0%
# Minor Defects Tot : 5.00% Minor Fruit Total : 6
# Major Defects Tot : 3.33% Major Fruit Total : 4 Packs With Major : 0%
# Box / Pack Weights : Avg 352g ; Min 335g; Max 375g Underweight 0%
# Weight Readings : 335 337 338 338 340 341 341 341 344 355 356 357 359 360 360 361 365 366 366
# 375
# Fruit Weights : Avg 44g 44
# Sugar Brix : Avg 19.29%; Min 16.30%; Max 21.60%
# Brix Readings : 16.3 17.1 17.7 19.1 19.4 20.0 20.1 20.2 21.4 21.6
# Size : Avg 0.00; Min 0; Max 0 Undersize 0.00%
# Size Readings :
# Maturity % : ST1: 0% ST2: 0% ST3: 0% ST4: 0% ST5: 0%
# Pressures : Avg 0.00 ; Min 0.00 ; Max 0.00
# Other Issues :
# QA Comments : Waste. Bruising. Dry splits. Scarring. Isolated puncture. Isolated condensation punnets.
# .
# Packs/Fruits Inspected/Sample Size : 120
# Boxes Inspected : 0
# C:\Users\LOCAL_~1.DZI\Temp\mdC75D.tmp Page 14 of 15
# --------Page: 15-----------
# Intake Pallet QC Inspection Report
# Customer DPS PO 166939 / ISS PO 204865
# Supplier Code : GUIM€
# Supplier : Guimera Fruits
# COO : Spain
# Vehicle No : Received : 03/09/2024 09:59:25
# Vessel : Inspection Date : 04/09/2024 06:35:59 Print date : 04/09/2024
# Apricots 20x320g Punnet
# ISS Pallet ID : 7761783 Freshness Technology :
# Supplier Pallet ID : 5808226 Punnet / Pad Type : N/A /
# Customer Pallet ID : 5808226 Outer :
# Variety : Fardao Brand : CORE
# Grower : / Organic? : NO Does Pallet Meet Spec? : YES
# GGN : / PLU? :
# AMBER Expected Qty 80
# Orchard/Farm : End Customer : Tesco
# Received Qty 80
# Harvest Date : 30/08/2024 DP : 7
# Total Defects : 10.83%
# Size/Calibre : 40/45 Packhouse :
# Estimated Yield : 94%
# Lot Number : 508177 Inspector : Hanna.Dziuba
# Waste : Waste: 2.5

# %%
import pandas as pd
flat_data = [item for sublist in response for item in sublist]

data = pd.DataFrame(flat_data)
data
# Out:
#                   product_name    RAG expected_qty received_qty supplier_code  \
# 0  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
# 1  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
# 2  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
# 3  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
# 4  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
# 5  Strawberries 20x227g Punnet  GREEN         1000         1000         12345
#
#     supplier  coo        received_date      inspection_date  print_date  ...  \
# 0  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
# 1  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
# 2  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
# 3  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
# 4  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
# 5  ABC Farms  USA  2023-04-15 10:30:00  2023-04-15 11:00:00  2023-04-15  ...
#
#    minor_fruit_total  major_defects_tot  major_fruit_total packs_with_major  \
# 0                 15                 20                 10                5
# 1                 15                 20                 10                5
# 2                 15                 20                 10                5
# 3                 15                 20                 10                5
# 4                 15                 20                 10                5
# 5                 15                 20                 10                5
#
#                box_pack_weights               weight_readings  \
# 0  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
# 1  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
# 2  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
# 3  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
# 4  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
# 5  227g, 227g, 227g, 227g, 227g  227g, 227g, 227g, 227g, 227g
#
#                   fruit_weights                      qa_comments  \
# 0  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
# 1  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
# 2  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
# 3  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
# 4  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
# 5  227g, 227g, 227g, 227g, 227g  Good quality, no major defects.
#
#   packs_fruits_inspected_sample_size boxes_inspected
# 0                                100              10
# 1                                100              10
# 2                                100              10
# 3                                100              10
# 4                                100              10
# 5                                100              10
#
# [6 rows x 41 columns]
